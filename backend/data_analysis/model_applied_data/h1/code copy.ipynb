# %%
import os
import pandas as pd

# Đường dẫn đến thư mục chứa các file CSV
folder_path = 'D:/KhoaLuanTotNghiep/tradebotsource/h1'


# Tạo một DataFrame full với header từ cột đầu tiên
full_df = pd.read_csv("EURUSD60-A2C.csv").iloc[:, :1]

# Lặp qua tất cả các file trong thư mục, bắt đầu từ file thứ hai
for filename in os.listdir(folder_path)[1:]:
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)
        # Đọc file CSV và chỉ lấy cột thứ hai
        df = pd.read_csv(file_path).iloc[:, 1]
        # Gộp full DataFrame với cột thứ hai của df
        full_df = pd.concat([full_df, df], axis=1)

# Đổi chiều dữ liệu của full DataFrame
full_df = full_df.T

# In ra kết quả
print(full_df)
# Out:
#                       0           1               2               3   \
# Unnamed: 0  Start Period  End Period  Risk-Free Rate  Time in Market
# Strategy      2023-04-17  2023-12-04            0.0%            8.0%
# Strategy      2023-04-17  2023-12-04            0.0%           15.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2023-04-17  2023-12-04            0.0%           23.0%
# Strategy      2023-04-17  2023-12-04            0.0%            4.0%
# Strategy      2023-04-17  2023-12-04            0.0%            2.0%
# Strategy      2023-04-17  2023-12-04            0.0%            4.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2023-04-17  2023-12-04            0.0%           23.0%
# Strategy      2023-04-17  2023-12-04            0.0%            3.0%
# Strategy      2023-04-17  2023-12-04            0.0%           23.0%
# Strategy      2023-04-17  2023-12-04            0.0%           17.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2023-04-17  2023-12-04            0.0%           25.0%
# Strategy      2023-04-17  2023-12-04            0.0%           20.0%
#
#                            4        5       6                   7   \
# Unnamed: 0  Cumulative Return    CAGR﹪  Sharpe  Prob. Sharpe Ratio
# Strategy               -5.72%   -6.25%   -0.26              14.91%
# Strategy              -13.43%  -14.61%   -1.15                0.0%
# Strategy                -3.7%   -0.17%  -11.14                0.0%
# Strategy               -3.83%   -0.18%  -11.53                0.0%
# Strategy              -24.22%  -26.21%   -1.54                0.0%
# Strategy               -4.06%   -4.44%   -1.11                0.0%
# Strategy               -3.98%   -4.35%   -0.17               24.7%
# Strategy               -5.13%    -5.6%   -0.23              17.36%
# Strategy               -3.64%   -0.17%   -8.44                0.0%
# Strategy               -2.64%   -0.12%   -6.23                0.0%
# Strategy              -19.46%  -21.11%   -1.42                0.0%
# Strategy               -4.04%   -4.42%   -0.19              21.92%
# Strategy               -2.95%   -3.22%   -0.18              23.45%
# Strategy               -4.99%   -5.46%   -0.34                9.5%
# Strategy              250.62%    5.89%     4.7              100.0%
# Strategy               244.1%     5.8%    4.77              100.0%
# Strategy               -4.49%   -4.91%   -0.24              17.62%
# Strategy               -0.84%   -0.92%   -0.04              43.42%
#
#                       8        9   ...        60         61           62  \
# Unnamed: 0  Smart Sharpe  Sortino  ...  Win Days  Win Month  Win Quarter
# Strategy           -0.26    -0.35  ...    43.32%     44.44%         0.0%
# Strategy           -1.15    -1.44  ...    35.82%     22.22%         0.0%
# Strategy           -6.59   -10.03  ...    16.51%      6.04%         0.0%
# Strategy           -6.87   -10.22  ...    15.93%      4.95%         0.0%
# Strategy           -1.53    -1.94  ...    34.55%       0.0%         0.0%
# Strategy            -1.1    -1.28  ...    25.93%       0.0%         0.0%
# Strategy           -0.17    -0.22  ...     48.1%     44.44%       33.33%
# Strategy           -0.23    -0.29  ...    47.86%     33.33%       33.33%
# Strategy           -5.03    -8.49  ...    22.29%     14.84%        9.84%
# Strategy           -3.68    -6.97  ...    27.23%     20.88%       14.75%
# Strategy           -1.41    -1.75  ...    39.42%     22.22%         0.0%
# Strategy           -0.19    -0.26  ...    43.81%     33.33%       33.33%
# Strategy           -0.18    -0.27  ...    47.19%     44.44%       66.67%
# Strategy           -0.34     -0.5  ...    45.45%     22.22%       33.33%
# Strategy            2.89     9.84  ...    65.91%     79.12%       90.16%
# Strategy            2.93    10.22  ...    65.05%     79.12%       86.89%
# Strategy           -0.24    -0.33  ...    47.43%     44.44%       33.33%
# Strategy           -0.04    -0.06  ...    47.34%     44.44%       33.33%
#
#                   63           64          65                   66  \
# Unnamed: 0  Win Year  Action Sell  Action Buy         Total Reward
# Strategy        0.0%         3650         301    285.3000000000376
# Strategy        0.0%         1101        2850   175.20000000001528
# Strategy        0.0%            0           0                    0
# Strategy        0.0%            0           0                    0
# Strategy        0.0%         2537        1414   -631.0000000000095
# Strategy        0.0%          144        3807  -200.39999999996502
# Strategy        0.0%         3872          79   -239.8999999999929
# Strategy        0.0%         3806         145  -131.60000000001205
# Strategy        0.0%            0           0                    0
# Strategy       6.25%            0           0                    0
# Strategy        0.0%         1398        2553   233.79999999997543
# Strategy        0.0%         3843         108   -47.40000000002013
# Strategy        0.0%         1403        2548    48099.99999999901
# Strategy        0.0%         1401        2550   -14939.99999998356
# Strategy      93.75%            0           0                    0
# Strategy      93.75%            0           0                    0
# Strategy        0.0%         2048        1903  -2110.0000000035543
# Strategy        0.0%         2027        1924     111489.999999999
#
#                             67        68      69
# Unnamed: 0        Total Profit    Ticket   Model
# Strategy     0.942802763271697  EURUSD60     A2C
# Strategy    0.8657141959754614  EURUSD60     DQN
# Strategy     9630.229000000047  EURUSD60     GRU
# Strategy     9616.743000000037  EURUSD60    LSTM
# Strategy    0.7577541328868922  EURUSD60     PPO
# Strategy    0.9576609915059829  EURUSD60  TR-DQN
# Strategy    0.9602153991396162  GBPUSD60     A2C
# Strategy    0.9487294014577096  GBPUSD60     DQN
# Strategy     9636.257000000036  GBPUSD60     GRU
# Strategy     9736.193000000038  GBPUSD60    LSTM
# Strategy    0.8054274220623565  GBPUSD60     PPO
# Strategy    0.9596249899183869  GBPUSD60  TR-DQN
# Strategy    0.9704950024795624  USDJPY60     A2C
# Strategy    0.9500534702606271  USDJPY60     DQN
# Strategy     35122.90000000009  USDJPY60     GRU
# Strategy     34470.30000000011  USDJPY60    LSTM
# Strategy    0.9550670605539905  USDJPY60     PPO
# Strategy    0.9915495096903895  USDJPY60  TR-DQN
#
# [19 rows x 70 columns]

# %%
full_df
# Out:
#                       0           1               2               3   \
# Unnamed: 0  Start Period  End Period  Risk-Free Rate  Time in Market
# Strategy      2023-04-17  2023-12-04            0.0%            8.0%
# Strategy      2023-04-17  2023-12-04            0.0%           15.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2023-04-17  2023-12-04            0.0%           23.0%
# Strategy      2023-04-17  2023-12-04            0.0%            4.0%
# Strategy      2023-04-17  2023-12-04            0.0%            2.0%
# Strategy      2023-04-17  2023-12-04            0.0%            4.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2023-04-17  2023-12-04            0.0%           23.0%
# Strategy      2023-04-17  2023-12-04            0.0%            3.0%
# Strategy      2023-04-17  2023-12-04            0.0%           23.0%
# Strategy      2023-04-17  2023-12-04            0.0%           17.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2023-04-17  2023-12-04            0.0%           25.0%
# Strategy      2023-04-17  2023-12-04            0.0%           20.0%
#
#                            4        5       6                   7   \
# Unnamed: 0  Cumulative Return    CAGR﹪  Sharpe  Prob. Sharpe Ratio
# Strategy               -5.72%   -6.25%   -0.26              14.91%
# Strategy              -13.43%  -14.61%   -1.15                0.0%
# Strategy                -3.7%   -0.17%  -11.14                0.0%
# Strategy               -3.83%   -0.18%  -11.53                0.0%
# Strategy              -24.22%  -26.21%   -1.54                0.0%
# Strategy               -4.06%   -4.44%   -1.11                0.0%
# Strategy               -3.98%   -4.35%   -0.17               24.7%
# Strategy               -5.13%    -5.6%   -0.23              17.36%
# Strategy               -3.64%   -0.17%   -8.44                0.0%
# Strategy               -2.64%   -0.12%   -6.23                0.0%
# Strategy              -19.46%  -21.11%   -1.42                0.0%
# Strategy               -4.04%   -4.42%   -0.19              21.92%
# Strategy               -2.95%   -3.22%   -0.18              23.45%
# Strategy               -4.99%   -5.46%   -0.34                9.5%
# Strategy              250.62%    5.89%     4.7              100.0%
# Strategy               244.1%     5.8%    4.77              100.0%
# Strategy               -4.49%   -4.91%   -0.24              17.62%
# Strategy               -0.84%   -0.92%   -0.04              43.42%
#
#                       8        9   ...        60         61           62  \
# Unnamed: 0  Smart Sharpe  Sortino  ...  Win Days  Win Month  Win Quarter
# Strategy           -0.26    -0.35  ...    43.32%     44.44%         0.0%
# Strategy           -1.15    -1.44  ...    35.82%     22.22%         0.0%
# Strategy           -6.59   -10.03  ...    16.51%      6.04%         0.0%
# Strategy           -6.87   -10.22  ...    15.93%      4.95%         0.0%
# Strategy           -1.53    -1.94  ...    34.55%       0.0%         0.0%
# Strategy            -1.1    -1.28  ...    25.93%       0.0%         0.0%
# Strategy           -0.17    -0.22  ...     48.1%     44.44%       33.33%
# Strategy           -0.23    -0.29  ...    47.86%     33.33%       33.33%
# Strategy           -5.03    -8.49  ...    22.29%     14.84%        9.84%
# Strategy           -3.68    -6.97  ...    27.23%     20.88%       14.75%
# Strategy           -1.41    -1.75  ...    39.42%     22.22%         0.0%
# Strategy           -0.19    -0.26  ...    43.81%     33.33%       33.33%
# Strategy           -0.18    -0.27  ...    47.19%     44.44%       66.67%
# Strategy           -0.34     -0.5  ...    45.45%     22.22%       33.33%
# Strategy            2.89     9.84  ...    65.91%     79.12%       90.16%
# Strategy            2.93    10.22  ...    65.05%     79.12%       86.89%
# Strategy           -0.24    -0.33  ...    47.43%     44.44%       33.33%
# Strategy           -0.04    -0.06  ...    47.34%     44.44%       33.33%
#
#                   63           64          65                   66  \
# Unnamed: 0  Win Year  Action Sell  Action Buy         Total Reward
# Strategy        0.0%         3650         301    285.3000000000376
# Strategy        0.0%         1101        2850   175.20000000001528
# Strategy        0.0%            0           0                    0
# Strategy        0.0%            0           0                    0
# Strategy        0.0%         2537        1414   -631.0000000000095
# Strategy        0.0%          144        3807  -200.39999999996502
# Strategy        0.0%         3872          79   -239.8999999999929
# Strategy        0.0%         3806         145  -131.60000000001205
# Strategy        0.0%            0           0                    0
# Strategy       6.25%            0           0                    0
# Strategy        0.0%         1398        2553   233.79999999997543
# Strategy        0.0%         3843         108   -47.40000000002013
# Strategy        0.0%         1403        2548    48099.99999999901
# Strategy        0.0%         1401        2550   -14939.99999998356
# Strategy      93.75%            0           0                    0
# Strategy      93.75%            0           0                    0
# Strategy        0.0%         2048        1903  -2110.0000000035543
# Strategy        0.0%         2027        1924     111489.999999999
#
#                             67        68      69
# Unnamed: 0        Total Profit    Ticket   Model
# Strategy     0.942802763271697  EURUSD60     A2C
# Strategy    0.8657141959754614  EURUSD60     DQN
# Strategy     9630.229000000047  EURUSD60     GRU
# Strategy     9616.743000000037  EURUSD60    LSTM
# Strategy    0.7577541328868922  EURUSD60     PPO
# Strategy    0.9576609915059829  EURUSD60  TR-DQN
# Strategy    0.9602153991396162  GBPUSD60     A2C
# Strategy    0.9487294014577096  GBPUSD60     DQN
# Strategy     9636.257000000036  GBPUSD60     GRU
# Strategy     9736.193000000038  GBPUSD60    LSTM
# Strategy    0.8054274220623565  GBPUSD60     PPO
# Strategy    0.9596249899183869  GBPUSD60  TR-DQN
# Strategy    0.9704950024795624  USDJPY60     A2C
# Strategy    0.9500534702606271  USDJPY60     DQN
# Strategy     35122.90000000009  USDJPY60     GRU
# Strategy     34470.30000000011  USDJPY60    LSTM
# Strategy    0.9550670605539905  USDJPY60     PPO
# Strategy    0.9915495096903895  USDJPY60  TR-DQN
#
# [19 rows x 70 columns]

# %%
# Loại bỏ cột đầu tiên "Unnamed: 0"
# full_df = full_df.drop(columns=['Unnamed: 0'])

# Di chuyển 4 cột cuối lên đầu
full_df = full_df[full_df.columns[-4:].tolist() + full_df.columns[:-4].tolist()]

# In ra kết quả
print(full_df)
# Out:
#                              66                  67        68      69  \
# Unnamed: 0         Total Reward        Total Profit    Ticket   Model
# Strategy      285.3000000000376   0.942802763271697  EURUSD60     A2C
# Strategy     175.20000000001528  0.8657141959754614  EURUSD60     DQN
# Strategy                      0   9630.229000000047  EURUSD60     GRU
# Strategy                      0   9616.743000000037  EURUSD60    LSTM
# Strategy     -631.0000000000095  0.7577541328868922  EURUSD60     PPO
# Strategy    -200.39999999996502  0.9576609915059829  EURUSD60  TR-DQN
# Strategy     -239.8999999999929  0.9602153991396162  GBPUSD60     A2C
# Strategy    -131.60000000001205  0.9487294014577096  GBPUSD60     DQN
# Strategy                      0   9636.257000000036  GBPUSD60     GRU
# Strategy                      0   9736.193000000038  GBPUSD60    LSTM
# Strategy     233.79999999997543  0.8054274220623565  GBPUSD60     PPO
# Strategy     -47.40000000002013  0.9596249899183869  GBPUSD60  TR-DQN
# Strategy      48099.99999999901  0.9704950024795624  USDJPY60     A2C
# Strategy     -14939.99999998356  0.9500534702606271  USDJPY60     DQN
# Strategy                      0   35122.90000000009  USDJPY60     GRU
# Strategy                      0   34470.30000000011  USDJPY60    LSTM
# Strategy    -2110.0000000035543  0.9550670605539905  USDJPY60     PPO
# Strategy       111489.999999999  0.9915495096903895  USDJPY60  TR-DQN
#
#                       0           1               2               3   \
# Unnamed: 0  Start Period  End Period  Risk-Free Rate  Time in Market
# Strategy      2023-04-17  2023-12-04            0.0%            8.0%
# Strategy      2023-04-17  2023-12-04            0.0%           15.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2023-04-17  2023-12-04            0.0%           23.0%
# Strategy      2023-04-17  2023-12-04            0.0%            4.0%
# Strategy      2023-04-17  2023-12-04            0.0%            2.0%
# Strategy      2023-04-17  2023-12-04            0.0%            4.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2023-04-17  2023-12-04            0.0%           23.0%
# Strategy      2023-04-17  2023-12-04            0.0%            3.0%
# Strategy      2023-04-17  2023-12-04            0.0%           23.0%
# Strategy      2023-04-17  2023-12-04            0.0%           17.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2020-01-01  2035-02-19            0.0%          100.0%
# Strategy      2023-04-17  2023-12-04            0.0%           25.0%
# Strategy      2023-04-17  2023-12-04            0.0%           20.0%
#
#                            4        5   ...           56              57  \
# Unnamed: 0  Cumulative Return    CAGR﹪  ...  Ulcer Index  Serenity Index
# Strategy               -5.72%   -6.25%  ...         0.04           -0.02
# Strategy              -13.43%  -14.61%  ...         0.07           -0.01
# Strategy                -3.7%   -0.17%  ...         0.02            -0.0
# Strategy               -3.83%   -0.18%  ...         0.02            -0.0
# Strategy              -24.22%  -26.21%  ...         0.14           -0.01
# Strategy               -4.06%   -4.44%  ...         0.02           -0.01
# Strategy               -3.98%   -4.35%  ...         0.03           -0.03
# Strategy               -5.13%    -5.6%  ...         0.03           -0.02
# Strategy               -3.64%   -0.17%  ...         0.02            -0.0
# Strategy               -2.64%   -0.12%  ...         0.02            -0.0
# Strategy              -19.46%  -21.11%  ...         0.12           -0.01
# Strategy               -4.04%   -4.42%  ...         0.03           -0.02
# Strategy               -2.95%   -3.22%  ...         0.04           -0.01
# Strategy               -4.99%   -5.46%  ...         0.04           -0.01
# Strategy              250.62%    5.89%  ...         0.01            6.44
# Strategy               244.1%     5.8%  ...         0.01            6.45
# Strategy               -4.49%   -4.91%  ...         0.06           -0.01
# Strategy               -0.84%   -0.92%  ...         0.03            -0.0
#
#                        58               59        60         61           62  \
# Unnamed: 0  Avg. Up Month  Avg. Down Month  Win Days  Win Month  Win Quarter
# Strategy            1.39%           -2.25%    43.32%     44.44%         0.0%
# Strategy            0.51%           -2.17%    35.82%     22.22%         0.0%
# Strategy             0.0%           -0.02%    16.51%      6.04%         0.0%
# Strategy            0.01%           -0.02%    15.93%      4.95%         0.0%
# Strategy                -           -3.01%    34.55%       0.0%         0.0%
# Strategy                -           -0.46%    25.93%       0.0%         0.0%
# Strategy            1.28%            -1.8%     48.1%     44.44%       33.33%
# Strategy            1.42%           -1.56%    47.86%     33.33%       33.33%
# Strategy            0.01%           -0.02%    22.29%     14.84%        9.84%
# Strategy            0.01%           -0.02%    27.23%     20.88%       14.75%
# Strategy             0.7%           -3.23%    39.42%     22.22%         0.0%
# Strategy            2.25%           -1.77%    43.81%     33.33%       33.33%
# Strategy            0.85%           -1.27%    47.19%     44.44%       66.67%
# Strategy            1.69%            -1.2%    45.45%     22.22%       33.33%
# Strategy            1.04%            -0.6%    65.91%     79.12%       90.16%
# Strategy            1.01%           -0.55%    65.05%     79.12%       86.89%
# Strategy            1.23%           -1.87%    47.43%     44.44%       33.33%
# Strategy            0.87%           -0.85%    47.34%     44.44%       33.33%
#
#                   63           64          65
# Unnamed: 0  Win Year  Action Sell  Action Buy
# Strategy        0.0%         3650         301
# Strategy        0.0%         1101        2850
# Strategy        0.0%            0           0
# Strategy        0.0%            0           0
# Strategy        0.0%         2537        1414
# Strategy        0.0%          144        3807
# Strategy        0.0%         3872          79
# Strategy        0.0%         3806         145
# Strategy        0.0%            0           0
# Strategy       6.25%            0           0
# Strategy        0.0%         1398        2553
# Strategy        0.0%         3843         108
# Strategy        0.0%         1403        2548
# Strategy        0.0%         1401        2550
# Strategy      93.75%            0           0
# Strategy      93.75%            0           0
# Strategy        0.0%         2048        1903
# Strategy        0.0%         2027        1924
#
# [19 rows x 70 columns]

# %%
full_df.to_csv('full_anaylytich1.csv', index=False)

# %%
full_read=pd.read_csv("full_anaylytich1.csv", header=1)

# %%
full_read
# Out:
#     Total Reward  Total Profit    Ticket   Model Start Period  End Period  \
# 0          285.3      0.942803  EURUSD60     A2C   2023-04-17  2023-12-04
# 1          175.2      0.865714  EURUSD60     DQN   2023-04-17  2023-12-04
# 2            0.0   9630.229000  EURUSD60     GRU   2020-01-01  2035-02-19
# 3            0.0   9616.743000  EURUSD60    LSTM   2020-01-01  2035-02-19
# 4         -631.0      0.757754  EURUSD60     PPO   2023-04-17  2023-12-04
# 5         -200.4      0.957661  EURUSD60  TR-DQN   2023-04-17  2023-12-04
# 6         -239.9      0.960215  GBPUSD60     A2C   2023-04-17  2023-12-04
# 7         -131.6      0.948729  GBPUSD60     DQN   2023-04-17  2023-12-04
# 8            0.0   9636.257000  GBPUSD60     GRU   2020-01-01  2035-02-19
# 9            0.0   9736.193000  GBPUSD60    LSTM   2020-01-01  2035-02-19
# 10         233.8      0.805427  GBPUSD60     PPO   2023-04-17  2023-12-04
# 11         -47.4      0.959625  GBPUSD60  TR-DQN   2023-04-17  2023-12-04
# 12       48100.0      0.970495  USDJPY60     A2C   2023-04-17  2023-12-04
# 13      -14940.0      0.950053  USDJPY60     DQN   2023-04-17  2023-12-04
# 14           0.0  35122.900000  USDJPY60     GRU   2020-01-01  2035-02-19
# 15           0.0  34470.300000  USDJPY60    LSTM   2020-01-01  2035-02-19
# 16       -2110.0      0.955067  USDJPY60     PPO   2023-04-17  2023-12-04
# 17      111490.0      0.991550  USDJPY60  TR-DQN   2023-04-17  2023-12-04
#
#    Risk-Free Rate Time in Market Cumulative Return    CAGR﹪  ...  Ulcer Index  \
# 0            0.0%           8.0%            -5.72%   -6.25%  ...         0.04
# 1            0.0%          15.0%           -13.43%  -14.61%  ...         0.07
# 2            0.0%         100.0%             -3.7%   -0.17%  ...         0.02
# 3            0.0%         100.0%            -3.83%   -0.18%  ...         0.02
# 4            0.0%          23.0%           -24.22%  -26.21%  ...         0.14
# 5            0.0%           4.0%            -4.06%   -4.44%  ...         0.02
# 6            0.0%           2.0%            -3.98%   -4.35%  ...         0.03
# 7            0.0%           4.0%            -5.13%    -5.6%  ...         0.03
# 8            0.0%         100.0%            -3.64%   -0.17%  ...         0.02
# 9            0.0%         100.0%            -2.64%   -0.12%  ...         0.02
# 10           0.0%          23.0%           -19.46%  -21.11%  ...         0.12
# 11           0.0%           3.0%            -4.04%   -4.42%  ...         0.03
# 12           0.0%          23.0%            -2.95%   -3.22%  ...         0.04
# 13           0.0%          17.0%            -4.99%   -5.46%  ...         0.04
# 14           0.0%         100.0%           250.62%    5.89%  ...         0.01
# 15           0.0%         100.0%            244.1%     5.8%  ...         0.01
# 16           0.0%          25.0%            -4.49%   -4.91%  ...         0.06
# 17           0.0%          20.0%            -0.84%   -0.92%  ...         0.03
#
#    Serenity Index  Avg. Up Month  Avg. Down Month  Win Days  Win Month  \
# 0           -0.02          1.39%           -2.25%    43.32%     44.44%
# 1           -0.01          0.51%           -2.17%    35.82%     22.22%
# 2           -0.00           0.0%           -0.02%    16.51%      6.04%
# 3           -0.00          0.01%           -0.02%    15.93%      4.95%
# 4           -0.01              -           -3.01%    34.55%       0.0%
# 5           -0.01              -           -0.46%    25.93%       0.0%
# 6           -0.03          1.28%            -1.8%     48.1%     44.44%
# 7           -0.02          1.42%           -1.56%    47.86%     33.33%
# 8           -0.00          0.01%           -0.02%    22.29%     14.84%
# 9           -0.00          0.01%           -0.02%    27.23%     20.88%
# 10          -0.01           0.7%           -3.23%    39.42%     22.22%
# 11          -0.02          2.25%           -1.77%    43.81%     33.33%
# 12          -0.01          0.85%           -1.27%    47.19%     44.44%
# 13          -0.01          1.69%            -1.2%    45.45%     22.22%
# 14           6.44          1.04%            -0.6%    65.91%     79.12%
# 15           6.45          1.01%           -0.55%    65.05%     79.12%
# 16          -0.01          1.23%           -1.87%    47.43%     44.44%
# 17          -0.00          0.87%           -0.85%    47.34%     44.44%
#
#     Win Quarter  Win Year Action Sell  Action Buy
# 0          0.0%      0.0%        3650         301
# 1          0.0%      0.0%        1101        2850
# 2          0.0%      0.0%           0           0
# 3          0.0%      0.0%           0           0
# 4          0.0%      0.0%        2537        1414
# 5          0.0%      0.0%         144        3807
# 6        33.33%      0.0%        3872          79
# 7        33.33%      0.0%        3806         145
# 8         9.84%      0.0%           0           0
# 9        14.75%     6.25%           0           0
# 10         0.0%      0.0%        1398        2553
# 11       33.33%      0.0%        3843         108
# 12       66.67%      0.0%        1403        2548
# 13       33.33%      0.0%        1401        2550
# 14       90.16%    93.75%           0           0
# 15       86.89%    93.75%           0           0
# 16       33.33%      0.0%        2048        1903
# 17       33.33%      0.0%        2027        1924
#
# [18 rows x 70 columns]

# %%
import pandas as pd
# Chọn 10 cột từ danh sách các cột bạn muốn lấy
selected_columns = [
    'Ticket',
    'Model',
    'Total Profit',
    'Sharpe',
    'Sortino',
    'Max Drawdown',
    'Gain/Pain Ratio',
    'Cumulative Return',
    'Max Consecutive Losses',
]

# Sử dụng operator [] để lấy ra các cột cụ thể
selected_df = full_read[selected_columns]

# In ra 5 dòng đầu của DataFrame sau khi đã lấy ra các cột
print(selected_df.head())
# Out:
#      Ticket Model  Total Profit  Sharpe  Sortino Max Drawdown  \
# 0  EURUSD60   A2C      0.942803   -0.26    -0.35       -7.81%
# 1  EURUSD60   DQN      0.865714   -1.15    -1.44      -13.76%
# 2  EURUSD60   GRU   9630.229000  -11.14   -10.03        -3.7%
# 3  EURUSD60  LSTM   9616.743000  -11.53   -10.22       -3.83%
# 4  EURUSD60   PPO      0.757754   -1.54    -1.94      -24.47%
#
#    Gain/Pain Ratio Cumulative Return  Max Consecutive Losses
# 0            -0.21            -5.72%                       1
# 1            -0.62           -13.43%                       1
# 2            -0.84             -3.7%                      71
# 3            -0.85            -3.83%                      78
# 4            -0.70           -24.22%                       1

# %%
selected_df
# Out:
#       Ticket   Model  Total Profit  Sharpe  Sortino Max Drawdown  \
# 0   EURUSD60     A2C      0.942803   -0.26    -0.35       -7.81%
# 1   EURUSD60     DQN      0.865714   -1.15    -1.44      -13.76%
# 2   EURUSD60     GRU   9630.229000  -11.14   -10.03        -3.7%
# 3   EURUSD60    LSTM   9616.743000  -11.53   -10.22       -3.83%
# 4   EURUSD60     PPO      0.757754   -1.54    -1.94      -24.47%
# 5   EURUSD60  TR-DQN      0.957661   -1.11    -1.28       -4.06%
# 6   GBPUSD60     A2C      0.960215   -0.17    -0.22       -6.11%
# 7   GBPUSD60     DQN      0.948729   -0.23    -0.29       -7.18%
# 8   GBPUSD60     GRU   9636.257000   -8.44    -8.49       -3.64%
# 9   GBPUSD60    LSTM   9736.193000   -6.23    -6.97       -2.64%
# 10  GBPUSD60     PPO      0.805427   -1.42    -1.75      -19.62%
# 11  GBPUSD60  TR-DQN      0.959625   -0.19    -0.26       -6.18%
# 12  USDJPY60     A2C      0.970495   -0.18    -0.27        -4.9%
# 13  USDJPY60     DQN      0.950053   -0.34    -0.50       -6.73%
# 14  USDJPY60     GRU  35122.900000    4.70     9.84       -5.27%
# 15  USDJPY60    LSTM  34470.300000    4.77    10.22       -4.74%
# 16  USDJPY60     PPO      0.955067   -0.24    -0.33      -10.01%
# 17  USDJPY60  TR-DQN      0.991550   -0.04    -0.06        -5.0%
#
#     Gain/Pain Ratio Cumulative Return  Max Consecutive Losses
# 0             -0.21            -5.72%                       1
# 1             -0.62           -13.43%                       1
# 2             -0.84             -3.7%                      71
# 3             -0.85            -3.83%                      78
# 4             -0.70           -24.22%                       1
# 5             -0.73            -4.06%                       1
# 6             -0.21            -3.98%                       1
# 7             -0.23            -5.13%                       1
# 8             -0.76            -3.64%                      77
# 9             -0.65            -2.64%                      61
# 10            -0.69           -19.46%                       1
# 11            -0.19            -4.04%                       1
# 12            -0.15            -2.95%                       1
# 13            -0.25            -4.99%                       1
# 14             1.72           250.62%                      12
# 15             1.75            244.1%                      17
# 16            -0.19            -4.49%                       1
# 17            -0.03            -0.84%                       1

# %%
# Loại bỏ dấu '%' và chuyển đổi thành số thực cho các cột kiểu chuỗi
for column in selected_df.columns[2:]:
    if selected_df[column].dtype == 'object':  # Kiểm tra kiểu chuỗi
        selected_df[column] = selected_df[column].str.replace('%', '').astype(float)
# Out:
# C:\Users\VuND\AppData\Local\Temp\ipykernel_16968\3892871477.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df[column] = selected_df[column].str.replace('%', '').astype(float)
# C:\Users\VuND\AppData\Local\Temp\ipykernel_16968\3892871477.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df[column] = selected_df[column].str.replace('%', '').astype(float)

# %%
selected_df.to_csv("selected_df.csv")

# %%
selected_df=pd.read_csv("selected_df.csv", index_col=0)

# %%
selected_df
# Out:
#       Ticket   Model  Total Profit  Sharpe  Sortino  Max Drawdown  \
# 0   EURUSD60     A2C      0.942803   -0.26    -0.35         -7.81
# 1   EURUSD60     DQN      0.865714   -1.15    -1.44        -13.76
# 2   EURUSD60     GRU     -0.962230  -11.14   -10.03         -3.70
# 3   EURUSD60    LSTM     -2.743000  -11.53   -10.22         -3.83
# 4   EURUSD60     PPO      0.757754   -1.54    -1.94        -24.47
# 5   EURUSD60  TR-DQN      0.957661   -1.11    -1.28         -4.06
# 6   GBPUSD60     A2C      0.960215   -0.17    -0.22         -6.11
# 7   GBPUSD60     DQN      0.948729   -0.23    -0.29         -7.18
# 8   GBPUSD60     GRU     -2.257000   -8.44    -8.49         -3.64
# 9   GBPUSD60    LSTM     -1.193000   -6.23    -6.97         -2.64
# 10  GBPUSD60     PPO      0.805427   -1.42    -1.75        -19.62
# 11  GBPUSD60  TR-DQN      0.959625   -0.19    -0.26         -6.18
# 12  USDJPY60     A2C      0.970495   -0.18    -0.27         -4.90
# 13  USDJPY60     DQN      0.950053   -0.34    -0.50         -6.73
# 14  USDJPY60     GRU     -0.900000    4.70     9.84         -5.27
# 15  USDJPY60    LSTM     -0.700000    4.77    10.22         -4.74
# 16  USDJPY60     PPO      0.955067   -0.24    -0.33        -10.01
# 17  USDJPY60  TR-DQN      0.991550   -0.04    -0.06         -5.00
#
#     Gain/Pain Ratio  Cumulative Return  Max Consecutive Losses
# 0             -0.21              -5.72                       1
# 1             -0.62             -13.43                       3
# 2             -0.84              -3.70                      71
# 3             -0.85              -3.83                      78
# 4             -0.70             -24.22                       4
# 5             -0.73              -4.06                       1
# 6             -0.21              -3.98                       3
# 7             -0.23              -5.13                       1
# 8             -0.76              -3.64                      77
# 9             -0.65              -2.64                      31
# 10            -0.69             -19.46                       1
# 11            -0.19              -4.04                       5
# 12            -0.15              -2.95                       2
# 13            -0.25              -4.99                       1
# 14             1.72             250.62                      12
# 15             1.75             244.10                      17
# 16            -0.19              -4.49                       1
# 17            -0.03              -0.84                       2

# %%
from sklearn.preprocessing import MinMaxScaler

columns_to_scale = ['Total Profit', 'Sharpe', 'Sortino', 'Max Drawdown', 
                    'Gain/Pain Ratio', 'Cumulative Return', 'Max Consecutive Losses']

# Áp dụng MinMaxScaler để scale các cột này về khoảng 0-1
scaler = MinMaxScaler()

# %%
# Assigning the provided weights to each criterion
weights = {
    "Total Profit": 0.20,
    "Sharpe": 0.10,
    "Sortino": 0.10,
    "Max Drawdown": -0.10,
    "Gain/Pain Ratio": 0.10,
    "Cumulative Return": 0.10,
    "Max Consecutive Losses": 0.10,
}
data = selected_df
data[columns_to_scale] = scaler.fit_transform(data[columns_to_scale])

# Normalize the data where necessary
# For ratios, higher is better, so we leave them as is.
# For Max Drawdown, Volatility, and Risk of Ruin, lower is better, so we will invert them.

# First, replacing negative values with 0 for ratios
data['Sharpe'] = data['Sharpe'].apply(lambda x: max(abs(x), 0))
data['Sortino'] = data['Sortino'].apply(lambda x: max(abs(x), 0))

# Inverting values where lower is better
data['Max Drawdown'] = data['Max Drawdown'].apply(lambda x: 1 / (abs(x) + 1))  # avoiding division by zero
data['Max Consecutive Losses'] = data['Max Consecutive Losses'].apply(lambda x: 1 / (abs(x) + 1))  # avoiding division by zero
data['Gain/Pain Ratio'] = data['Gain/Pain Ratio'].apply(lambda x: 1 / (abs(x) + 1))  # avoiding division by zero

# Calculating the weighted sum for each row
score_columns = list(weights.keys())
data['Weighted Score'] = data[score_columns].mul(list(weights.values())).sum(axis=1)

# Sorting the dataframe based on the weighted score
sorted_data = data.sort_values(by='Weighted Score', ascending=False)

# Display the top models based on the weighted score
sorted_data[['Ticket', 'Model', 'Weighted Score']].head()
# Out:
#       Ticket   Model  Weighted Score
# 15  USDJPY60    LSTM        0.487308
# 14  USDJPY60     GRU        0.480997
# 5   EURUSD60  TR-DQN        0.457092
# 17  USDJPY60  TR-DQN        0.450588
# 12  USDJPY60     A2C        0.449699

# %%
sorted_data
# Out:
#       Ticket   Model  Total Profit    Sharpe   Sortino  Max Drawdown  \
# 15  USDJPY60    LSTM      0.547054  1.000000  1.000000      0.525265
# 14  USDJPY60     GRU      0.493500  0.995706  0.981409      0.532050
# 5   EURUSD60  TR-DQN      0.990926  0.639264  0.437378      0.516809
# 17  USDJPY60  TR-DQN      1.000000  0.704908  0.497065      0.528571
# 12  USDJPY60     A2C      0.994362  0.696319  0.486791      0.527295
# 6   GBPUSD60     A2C      0.991610  0.696933  0.489237      0.543170
# 7   GBPUSD60     DQN      0.988534  0.693252  0.485812      0.558027
# 13  USDJPY60     DQN      0.988889  0.686503  0.475538      0.551681
# 0   EURUSD60     A2C      0.986947  0.691411  0.482877      0.567160
# 11  GBPUSD60  TR-DQN      0.991452  0.695706  0.487280      0.544118
# 16  USDJPY60     PPO      0.990231  0.692638  0.483855      0.601543
# 1   EURUSD60     DQN      0.966305  0.636810  0.429550      0.670867
# 10  GBPUSD60     PPO      0.950162  0.620245  0.414384      0.818216
# 4   EURUSD60     PPO      0.937397  0.612883  0.405088      1.000000
# 9   GBPUSD60    LSTM      0.415043  0.325153  0.159002      0.500000
# 2   EURUSD60     GRU      0.476837  0.023926  0.009295      0.512441
# 8   GBPUSD60     GRU      0.130136  0.189571  0.084638      0.511721
# 3   EURUSD60    LSTM      0.000000  0.000000  0.000000      0.514010
#
#     Gain/Pain Ratio  Cumulative Return  Max Consecutive Losses  Weighted Score
# 15         0.500000           0.976277                0.827957        0.487308
# 14         0.502901           1.000000                0.875000        0.480997
# 5          0.955882           0.073352                1.000000        0.457092
# 17         0.760234           0.085068                0.987179        0.450588
# 12         0.787879           0.077390                0.987179        0.449699
# 6          0.802469           0.073643                0.974684        0.447701
# 7          0.807453           0.069459                1.000000        0.447502
# 13         0.812500           0.069968                1.000000        0.447061
# 0          0.802469           0.067312                1.000000        0.445080
# 11         0.797546           0.073425                0.950617        0.444336
# 16         0.797546           0.071787                1.000000        0.442475
# 1          0.918728           0.039259                0.974684        0.426077
# 10         0.942029           0.017319                1.000000        0.407609
# 4          0.945455           0.000000                0.962500        0.380072
# 9          0.928571           0.078518                0.719626        0.254096
# 2          0.996169           0.074662                0.523810        0.206909
# 8          0.966543           0.074880                0.503268        0.156745
# 3          1.000000           0.074189                0.500000        0.106018

# %%
df_float_uploaded = sorted_data.select_dtypes(include=['float'])
sorted_data[df_float_uploaded.columns] = df_float_uploaded.round(4)

# Display the first few rows of the rounded DataFrame
df_rounded_uploaded = sorted_data.head()
df_rounded_uploaded
# Out:
#       Ticket   Model  Total Profit  Sharpe  Sortino  Max Drawdown  \
# 15  USDJPY60    LSTM        0.5471  1.0000   1.0000        0.5253
# 14  USDJPY60     GRU        0.4935  0.9957   0.9814        0.5320
# 5   EURUSD60  TR-DQN        0.9909  0.6393   0.4374        0.5168
# 17  USDJPY60  TR-DQN        1.0000  0.7049   0.4971        0.5286
# 12  USDJPY60     A2C        0.9944  0.6963   0.4868        0.5273
#
#     Gain/Pain Ratio  Cumulative Return  Max Consecutive Losses  Weighted Score
# 15           0.5000             0.9763                  0.8280          0.4873
# 14           0.5029             1.0000                  0.8750          0.4810
# 5            0.9559             0.0734                  1.0000          0.4571
# 17           0.7602             0.0851                  0.9872          0.4506
# 12           0.7879             0.0774                  0.9872          0.4497

# %%
sorted_data.to_csv('wsh1.csv',index=False)
