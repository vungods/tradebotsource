# %%
import pandas as pd
df= pd.read_csv("EURUSD60_data.csv")

# %%
df[['datadate','tic','adjcp','adjcp','high','low','volume']]
# Out:
#            datadate       tic    adjcp    adjcp     high      low  volume
# 0      202010010000  EURUSD60  1.17234  1.17234  1.17171  1.17182   38415
# 1      202010010100  EURUSD60  1.17182  1.17182  1.17177  1.17339   40377
# 2      202010010200  EURUSD60  1.17340  1.17340  1.17330  1.17408   22499
# 3      202010010300  EURUSD60  1.17408  1.17408  1.17386  1.17435   15842
# 4      202010010400  EURUSD60  1.17436  1.17436  1.17401  1.17472   14763
# ...             ...       ...      ...      ...      ...      ...     ...
# 19803  202312032300  EURUSD60  1.08834  1.08834  1.08795  1.08857   12475
# 19804  202312040000  EURUSD60  1.08858  1.08858  1.08699  1.08716   12284
# 19805  202312040100  EURUSD60  1.08715  1.08715  1.08665  1.08731   15463
# 19806  202312040200  EURUSD60  1.08730  1.08730  1.08699  1.08826    8082
# 19807  202312040300  EURUSD60  1.08826  1.08826  1.08800  1.08801    6947
#
# [19808 rows x 7 columns]
